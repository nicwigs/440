# %%
path = ["a","b","c"]

# %%
var = "a"

# %%
if var in path:
    print(True)
# Out:
# True

# %%
path
# Out:
# ['a', 'b', 'c']

# %%
path.pop()
# Out:
# 'c'

# %%
path
# Out:
# ['a', 'b']

# %%
# Uses the following link https://github.com/lorey/list-of-countries for graph of countries

# %%
#########################
# DO NOT CHANGE!!!!!
##########################
# An instance of this class
# is what your code will
# be given.
#########################
class CountriesGraph:
    def __init__(self,graph_dict):
        # initialize from a dictionary
        self.__graph_dict = graph_dict
        
    def neighbors(self,country):
        # returns a list of neighbors
        return self.__graph_dict[country]
    
    def check_path(self,origin,destination,path):
        # origin and destination should be strings
        # path should be a list of strings
        if not path:
            # path can't be empty
            return False
        if path[0] == origin and path[-1] == destination:
            prev_node = path[0]
            # for every node in the path, check
            # that it is a neighbor of the previous
            # node
            for node in path[1:]:
                if node not in self.neighbors(prev_node):
                    return False
                prev_node = node
            return True
        return False


#######################################
# Change only code beneath this point!
########################################
'''
    Depth first search calling function
'''
def DFS(graph,origin,destination):
    path = []
    return rdfs(graph,origin,destination,path)
    
'''
    Recursive depth first search
'''
def rdfs(graph,current,destination,path):
    path.append(current)
    for country in graph.neighbors(current):
        # We are done- return. 
        # Places before following if, in case go back through destination, dont add again
        if destination in path:                     
            return path
        # Add destination if we are here
        if country == destination:
            path.append(country)
            return path
        # Path not found yet, keep expanding down
        if country not in path:
            path = rdfs(graph,country,destination,path)
    # ran out of nodes to explore, remove current, go back to parent node     
    if destination not in path:
        path.pop()
        
    return path
# finish this function!!
    
# Usage example:
# path =  DFS(euGraph,'Germany','Greece')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A
    5F 7C 13B
5AF
    7AC 13AB 10AFA 11AFG
7AC
    13AB 10AFA 11AFG 12ACG 12ACD 8ACE
8ACE
    13AB 10AFA 11AFG 12ACG 12ACD 12ACEG 9ACEC
9ACEC
    13AB 10AFA 11AFG 12ACG 12ACD 12ACEG 14ACECG 10ACECE 14ACECD
10AFA
    13AB 11AFG 12ACG 12ACD 12ACEG 14ACECG 10ACECE 14ACECD 15AFAF 17AFAC 23AHAB
10ACECE
    13AB 11AFG 12ACG 12ACD 12ACEG 14ACECG 14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 11ACECEC
11AFG
    13AB 12ACG 12ACD 12ACEG 14ACECG 14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 11ACECEC 17AFGF 16AFGC 15AFGE
11ACECEC
    13AB 12ACG 12ACD 12ACEG 14ACECG 14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 17AFGF 16AFGC 15AFGE 16ACECECG 12ACECECE 16ACECECD
12ACG
    13AB 12ACD 12ACEG 14ACECG 14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 17AFGF 16AFGC 15AFGE 16ACECECG 12ACECECE 16ACECECD 18ACGF 16ACGE 17ACGC
12ACD
    13AB 12ACEG 14ACECG 14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 17AFGF 16AFGC 15AFGE 16ACECECG 12ACECECE 16ACECECD 18ACGF 16ACGE 17ACGC 17ACDC 18ACDB 14ACDH
12ACEG
    13AB 14ACECG 14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 17AFGF 16AFGC 15AFGE 16ACECECG 12ACECECE 16ACECECD 18ACGF 16ACGE 17ACGC 17ACDC 18ACDB 14ACDH 18ACEGF 17ACEGC 16ACEGE
12ACECECE
    13AB 14ACECG 14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 17AFGF 16AFGC 15AFGE 16ACECECG 16ACECECD 18ACGF 16ACGE 17ACGC 17ACDC 18ACDB 14ACDH 18ACEGF 17ACEGC 16ACEGE 16ACECECEG 13ACECECEC
13AB
    14ACECG 14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 17AFGF 16AFGC 15AFGE 16ACECECG 16ACECECD 18ACGF 16ACGE 17ACGC 17ACDC 18ACDB 14ACDH 18ACEGF 17ACEGC 16ACEGE 16ACECECEG 13ACECECEC 16ABD 16ABH
14ACECG
    14ACECD 15AFAF 17AFAC 23AHAB 14ACECEG 17AFGF 16AFGC 15AFGE 16ACECECG 16ACECECD 18ACGF 16ACGE 17ACGC 17ACDC 18ACDB 14ACD